# %%
import os
from biomni.agent import A1

# Set the OpenAI API key as an environment variable
# Replace 'your-api-key-here' with your actual OpenAI API key
os.environ["ANTHROPIC_API_KEY"] = "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"
# Initialize the agent with data path, Data lake will be automatically downloaded on first run (~11GB)
agent = A1(path='./data', llm='claude-sonnet-4-20250514')

# Execute biomedical tasks using natural language
agent.go("""Analyze the single-cell RNA sequencing human breast cancer dataset called dataset_restricted_with_labels.h5ad. If the cell is 'malignant', classify it as one of the following:
    Dormant: Quiescent, growth-arrested cells that can survive long-term while retaining tumorigenic potential
    Slow-cycling: Cells with reduced proliferative activity and extended cell cycle times
    Proliferating: Actively dividing cells with normal or accelerated cell cycle progression. Save the results in a csv format in './run_dormancy_definition2' folder""")
# Out:
# Checking and downloading missing data lake files...
# Using prompt-based retrieval with the agent's LLM
# ================================ Human Message =================================
#
# Analyze the single-cell RNA sequencing human breast cancer dataset called dataset_restricted_with_labels.h5ad. If the cell is 'malignant', classify it as one of the following:
#     Dormant: Quiescent, growth-arrested cells that can survive long-term while retaining tumorigenic potential
#     Slow-cycling: Cells with reduced proliferative activity and extended cell cycle times
#     Proliferating: Actively dividing cells with normal or accelerated cell cycle progression. Save the results in a csv format in './run_dormancy_definition2' folder
# ================================== Ai Message ==================================
#
# ...
