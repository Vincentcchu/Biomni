# %%
import os
from biomni.agent import A1
import json

# Set the OpenAI API key as an environment variable
# Load API from json file

with open('config.json') as f:
    config = json.load(f)

os.environ["ANTHROPIC_API_KEY"] = config["ANTHROPIC_API_KEY"]# Initialize the agent with data path, Data lake will be automatically downloaded on first run (~11GB)
agent = A1(path='./data', llm='claude-sonnet-4-20250514')

# Execute biomedical tasks using natural language
agent.go("Analyze the single-cell RNA sequencing human breast cancer dataset called biomni1.h5ad. If the cell is 'malignant', classify it as either 'quiescent', 'proliferative' or 'slow-cycling'. Save the results in a csv format in './run_dormancy' folder")
# Out:
# Checking and downloading missing data lake files...
# Using prompt-based retrieval with the agent's LLM
# ================================ Human Message =================================
#
# Analyze the single-cell RNA sequencing human breast cancer dataset called biomni1.h5ad. If the cell is 'malignant', classify it as either 'quiescent', 'proliferative' or 'slow-cycling'. Save the results in a csv format in './run_cluster' folder
# ================================== Ai Message ==================================
#
# I'll help you analyze the single-cell RNA sequencing human breast cancer dataset and classify malignant cells based on their proliferative states. Let me start by creating a plan.
#
# ## Plan:
#
# 1. [ ] Load and explore the dataset to understand its structure
# 2. [ ] Examine the existing cell type annotations and identify malignant cells
# 3. [ ] Analyze gene expression patterns related to cell cycle and proliferation
# ...
